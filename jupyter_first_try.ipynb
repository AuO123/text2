# %%
print("hello,it is my first jupyter Notebook")

result = 5+3
print(f"5+3 = {result}")
# Out:
# hello,it is my first jupyter Notebook
# 5+3 = 8

# %%
a=10
b=5
sum= a+b
print(F"a+b={sum}")
# Out:
# a+b=15

# %%
difference =a-b
print(f"a-b={difference}")
# Out:
# a-b=5
